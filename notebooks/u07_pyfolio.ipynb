# %% [markdown]
# 請開啟任意 anaconda prompt
# 輸入：
#
# conda activate finlab
#
# conda install -c conda-forge bottleneck
#
# pip install pyfolio==0.9.2
#
# 然後再執行以下程式喔！

# %% [markdown]
# # 0050 測試

# %%
# 移除不必要的警告
import warnings
warnings.filterwarnings('ignore')

# 獲取0050收盤價資料
from finlab.data import Data
data = Data()
close = data.get_adj("收盤價")

# 將收盤假日期調整，這樣子等等使用pyfolio才不會有問題
close.index = close.index.tz_localize("Asia/Taipei")

# 每天報酬率繪圖
# %matplotlib inline
close['0050'].pct_change().plot()

# %% [markdown]
# # 使用 Pyfolio 觀察個股報酬率

# %%
import pyfolio as pf

pf.create_returns_tear_sheet(close['0050'].pct_change())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2007-04-23</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-13</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>149</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.8%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>154.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.48</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.14</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.81</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-55.8%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.68</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.5%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>55.75</td>
#       <td>2007-10-29</td>
#       <td>2008-11-20</td>
#       <td>2011-01-28</td>
#       <td>850</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>23.01</td>
#       <td>2011-01-28</td>
#       <td>2011-12-19</td>
#       <td>2013-05-16</td>
#       <td>600</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20.96</td>
#       <td>2015-04-27</td>
#       <td>2015-08-24</td>
#       <td>2016-08-08</td>
#       <td>336</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.53</td>
#       <td>2018-08-30</td>
#       <td>2019-01-04</td>
#       <td>2019-09-16</td>
#       <td>273</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14.55</td>
#       <td>2007-07-25</td>
#       <td>2007-08-16</td>
#       <td>2007-10-02</td>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle
import pandas as pd

# 得到 上一個單元的 回測結果
ret = pickle.load(open("return_history.pkl", "rb"))

# 將回測報酬率取出來
ret = ret.pct_change().dropna()
ret.index = pd.to_datetime(ret.index).tz_localize('Asia/Taipei')

# 利用pyfolio 比較報酬率
pf.create_returns_tear_sheet(ret, benchmark_rets=close['0050'].pct_change())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2007-04-24</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-13</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>148</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>162.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>10.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.72</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-11.2%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.21</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.05</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>22.47</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.29</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.2%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.08</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11.18</td>
#       <td>2014-09-23</td>
#       <td>2014-10-16</td>
#       <td>2015-04-24</td>
#       <td>154</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.14</td>
#       <td>2012-02-29</td>
#       <td>2012-08-30</td>
#       <td>2013-07-15</td>
#       <td>359</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8.23</td>
#       <td>2016-03-22</td>
#       <td>2016-05-13</td>
#       <td>2016-06-30</td>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7.72</td>
#       <td>2010-01-15</td>
#       <td>2010-06-04</td>
#       <td>2010-07-08</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.52</td>
#       <td>2017-09-18</td>
#       <td>2018-02-09</td>
#       <td>2018-06-07</td>
#       <td>189</td>
#     </tr>
#   </tbody>
# </table>
